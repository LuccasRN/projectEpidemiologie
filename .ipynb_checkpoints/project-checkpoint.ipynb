# %% [markdown]
# init jeu de donnees

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# A compléter
df_h1 = pd.read_json('./liver.json')
df_h2 = pd.read_csv('./liver.csv')
df_h1.head()
df_h2.head()

# %% [markdown]
# combination donnees

# %%
df_combined = pd.concat([df_h1, df_h2], ignore_index=True)
df_combined.head()
# Out:
#            Age  Gender  Total_Bilirubin  Direct_Bilirubin  \
# 0  61 to 80 yo  Female              0.7               0.1
# 1  61 to 80 yo    Male             10.9               5.5
# 2  61 to 80 yo    Male              7.3               4.1
# 3  41 to 60 yo    Male              1.0               0.4
# 4  61 to 80 yo    Male              3.9               2.0
#
#    Alkaline_Phosphotase  Alamine_Aminotransferase  Aspartate_Aminotransferase  \
# 0                 187.0                       NaN                        18.0
# 1                 699.0                      64.0                       100.0
# 2                 490.0                       NaN                        68.0
# 3                 182.0                      14.0                        20.0
# 4                 195.0                      27.0                        59.0
#
#   Total_Proteins  Albumin  Albumin_and_Globulin_Ratio  Outcome  ALT  AST  \
# 0            6.8      3.3                        0.90      1.0  NaN  NaN
# 1            7.5      NaN                        0.74      1.0  NaN  NaN
# 2            7.0      3.3                         NaN      1.0  NaN  NaN
# 3            6.8      3.4                        1.00      1.0  NaN  NaN
# 4            7.3      2.4                        0.40      1.0  NaN  NaN
#
#    Result
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %% [markdown]
# afficher information
