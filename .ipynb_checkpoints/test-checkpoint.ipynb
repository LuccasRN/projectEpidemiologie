# %% [markdown]
# init jeu de donnees

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# A compléter
df_h1 = pd.read_json('./hopital1.json')
df_h2 = pd.read_csv('./hopital2.csv')
df_h1.head()
df_h2.head()
